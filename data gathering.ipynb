# %%
from etsy2 import Etsy
import json
import requests
import pandas as pd

# %%
etsy = Etsy(api_key='h3sb155lstj9j1pztllhyuzt')

# %%
etsy.findAllFeaturedListings()
# Out:
# [{'listing_id': 55086613,
#   'state': 'vacation',
#   'user_id': 6225648,
#   'category_id': None,
#   'title': 'Clink illustration print - rosy pink cheeks nerds kissing - perfect gift for your love, a wedding, valentine, or anniversary',
#   'description': 'Boy meets girl.\nGirl meets boy.\nBoy almost head-butts girl while trying to kiss her.\nNerdy glasses save.\n\n**Please note that the print itself with not have &quot;© Genevieve Santos &quot; printed on it. I had to include the watermark/copyright because too many people were stealing the image from this Etsy listing.\n\n&quot;Clink&quot; is an 8&quot; x 10&quot; printed with a professional 8-color printer on heavy watercolor paper. The original is a pencil drawing.\n\nEach print is signed and packaged in a protective plastic sleeve and padded envelope. \n\n© Genevieve Santos',
#   'creation_tsz': 1608242443,
#   'ending_tsz': 1618693243,
#   'original_creation_tsz': 1283188272,
#   'last_modified_tsz': 1608242443,
# ...

# %%
df_featured = pd.DataFrame(etsy.findAllFeaturedListings(limit=10))
df_featured
# Out:
#    listing_id     state     user_id  category_id  \
# 0    55086613  vacation   6225648.0          NaN
# 1    80389047    active  10779498.0          NaN
# 2    83144130  sold_out  11756129.0          NaN
# 3    91933170      edit         NaN          NaN
# 4   113029968      edit         NaN          NaN
# 5   154109230      edit         NaN          NaN
# 6   176459361  sold_out  16843469.0          NaN
# 7   178963554  sold_out  22747148.0          NaN
# 8   181243834  sold_out   8005344.0          NaN
# 9   183078144   removed         NaN          NaN
#
#                                                title  \
# 0  Clink illustration print - rosy pink cheeks ne...
# 1  Letter Holder, Wood Mail Organizer, Desk Organ...
# 2  Set of 3 Spora w/ leather: porcelain hanging p...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ...

# %%
etsy.findAllListingActive()
# Out:
# [{'listing_id': 962130537,
#   'state': 'active',
#   'user_id': 6520880,
#   'category_id': None,
#   'title': 'Brass Star Charm, 12 Raw Brass Moon Phases Charms With 1 Hole (22x14x0.80mm) M01545',
#   'description': 'Raw Brass Moon Phases Charms With 1 Hole\n\nMaterial : Brass\nSize : 22x14x0.80mm\nHole Size : 1.5mm\nQuantity : 12 Pieces\n\n\nFor more blanks, please see here: \nhttps://www.etsy.com/shop/yakutum?ref=hdr_shop_menu&search_query=blank\n\nFor more moon items please see here :\nhttps://www.etsy.com/shop/yakutum?ref=hdr_shop_menu\n\nFor more yakutum items, please see here:\nhttps://www.etsy.com/shop/yakutum?ref=hdr_shop_menu\n\nEnjoy!',
#   'creation_tsz': 1614035375,
#   'ending_tsz': 1624399775,
#   'original_creation_tsz': 1613196275,
#   'last_modified_tsz': 1614035375,
#   'price': '3.00',
#   'currency_code': 'USD',
#   'quantity': 749,
#   'sku': ['M01545'],
#   'tags': ['half moon',
#    'diy jewelry',
#    'jewelry supplies',
#    'gift for her',
# ...

# %%
etsy.findAllListingFavoredBy(listing_id = 962130537)
# Out:
# [{'listing_id': 962130537,
#   'listing_state': 'active',
#   'create_date': 1614033629},
#  {'listing_id': 962130537,
#   'user_id': 48509061,
#   'listing_state': 'active',
#   'create_date': 1613942731},
#  {'listing_id': 962130537,
#   'user_id': 98235971,
#   'listing_state': 'active',
#   'create_date': 1613885642},
#  {'listing_id': 962130537,
#   'user_id': 36945790,
#   'listing_state': 'active',
#   'create_date': 1613798792},
#  {'listing_id': 962130537,
#   'listing_state': 'active',
#   'create_date': 1613264731}]

# %%
etsy.findAllShops(limit=1)
# Out:
# [{'shop_id': 28016037,
#   'shop_name': 'Caraiedomiceq',
#   'user_id': 451988257,
#   'creation_tsz': 1614060192,
#   'title': None,
#   'announcement': None,
#   'currency_code': 'GBP',
#   'is_vacation': False,
#   'vacation_message': None,
#   'sale_message': None,
#   'digital_sale_message': None,
#   'last_updated_tsz': 1614060192,
#   'listing_active_count': 1,
#   'digital_listing_count': 0,
#   'login_name': 'mkjzosk12a7q3wip',
#   'accepts_custom_requests': False,
#   'policy_welcome': None,
#   'policy_payment': None,
#   'policy_shipping': None,
#   'policy_refunds': None,
#   'policy_additional': None,
#   'policy_seller_info': None,
#   'policy_updated_tsz': 0,
#   'policy_has_private_receipt_info': False,
#   'vacation_autoreply': None,
#   'url': 'https://www.etsy.com/shop/Caraiedomiceq?utm_source=kellycap&utm_medium=api&utm_campaign=api',
#   'image_url_760x100': None,
#   'num_favorers': 0,
#   'languages': ['en-US'],
#   'upcoming_local_event_id': None,
# ...

# %%
# api_key = 'h3sb155lstj9j1pztllhyuzt'
# shared_secret = '8ilsqvz0bd'

# %%
#listing = json.loads('https://openapi.etsy.com/v2/listings/active?api_key=h3sb155lstj9j1pztllhyuzt')

# %%
#https://openapi.etsy.com/v2/listings/active?api_key=h3sb155lstj9j1pztllhyuzt

# %%
df = pd.DataFrame(etsy.getTrendingListings(limit=10))

# %%
df
# Out:
#    listing_id     state      user_id  category_id  \
# 0   484595996    active    5674258.0          NaN
# 1   540069702      edit          NaN          NaN
# 2   540334292  a_closed          NaN          NaN
# 3   551966633    active   56404851.0          NaN
# 4   539359874      edit          NaN          NaN
# 5   544748121      edit          NaN          NaN
# 6   290789947   expired          NaN          NaN
# 7   553605703      edit          NaN          NaN
# 8   539988010  sold_out  103433826.0          NaN
# 9   553943075    active   39280796.0          NaN
#
#                                                title  \
# 0  Upper and Lower Case Alphabet Watercolor Brush...
# 1                                                NaN
# 2                                                NaN
# 3  Jewelry Display Box Jewelry organizer Glass bo...
# 4                                                NaN
# 5                                                NaN
# ...

# %%
# response = requests.get("https://openapi.etsy.com/v2/listings/active?api_key=h3sb155lstj9j1pztllhyuzt")

# %%
# listings = json.loads(response.text)

# %%
# listings

# %%
# needs OAuth 
# etsy.findAllListingTransactions(listing_id=55086613)

# %%
# Trending listings

# https://openapi.etsy.com/v2/listings/trending?api_key=h3sb155lstj9j1pztllhyuzt&limit=100

# %%
## functions for reading in the data
